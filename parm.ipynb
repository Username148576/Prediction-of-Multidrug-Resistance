# %%
nround = [i for i in range(40, 201, 10)]
eta = [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.25, 0.3]
max_depth = [2, 4, 6, 8, 10,12]

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


train = pd.read_csv('./data/train.csv')
label_train = pd.read_csv('./data/label_train.csv')

# Define the parameter grid for grid search
param_grid = {
    'n_estimators': range(40, 121, 10),
    'eta': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.25, 0.3, 0.5],
    'max_depth': [2, 4, 6, 8, 10, 12]
}

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(train, label_train['CIP'], test_size=0.3, random_state=1)

# Perform grid search with cross-validation
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123)
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the final model with the best hyperparameters
final_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123, **best_params)
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred = final_model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, y_pred)
print("AUC Score on Test Set:", auc_score)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Best Hyperparameters: {'eta': 0.2, 'max_depth': 8, 'n_estimators': 120}
# AUC Score on Test Set: 0.9649717663589038

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


train = pd.read_csv('./data/train.csv')
label_train = pd.read_csv('./data/label_train.csv')

# Define the parameter grid for grid search
param_grid = {
    'n_estimators': range(40, 201, 10),
    'eta': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.25, 0.3, 0.5],
    'max_depth': [2, 4, 6, 8, 10, 12]
}

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(train, label_train['FEP'], test_size=0.3, random_state=1)

# Perform grid search with cross-validation
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123)
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the final model with the best hyperparameters
final_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123, **best_params)
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred = final_model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, y_pred)
print("AUC Score on Test Set:", auc_score)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fitting 5 folds for each of 918 candidates, totalling 4590 fits
# Best Hyperparameters: {'eta': 0.1, 'max_depth': 8, 'n_estimators': 190}
# AUC Score on Test Set: 0.9582113854710989

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


train = pd.read_csv('./data/train.csv')
label_train = pd.read_csv('./data/label_train.csv')

# Define the parameter grid for grid search
param_grid = {
    'n_estimators': range(40, 201, 10),
    'eta': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.25, 0.3, 0.5],
    'max_depth': [2, 4, 6, 8, 10, 12]
}

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(train, label_train['MEM'], test_size=0.3, random_state=1)

# Perform grid search with cross-validation
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123)
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the final model with the best hyperparameters
final_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123, **best_params)
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred = final_model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, y_pred)
print("AUC Score on Test Set:", auc_score)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fitting 5 folds for each of 918 candidates, totalling 4590 fits
# Best Hyperparameters: {'eta': 0.1, 'max_depth': 12, 'n_estimators': 200}
# AUC Score on Test Set: 0.9390126534389565

# %%
param_grid = {
    'n_estimators': range(130, 201, 10),
    'eta': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.25, 0.3, 0.5],
    'max_depth': [2, 4, 6, 8, 10, 12]
}

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(train, label_train['CIP'], test_size=0.3, random_state=1)

# Perform grid search with cross-validation
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123)
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the final model with the best hyperparameters
final_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123, **best_params)
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred = final_model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, y_pred)
print("AUC Score on Test Set:", auc_score)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# Best Hyperparameters: {'eta': 0.2, 'max_depth': 8, 'n_estimators': 190}
# AUC Score on Test Set: 0.9649958700400062

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


train = pd.read_csv('./data/train.csv')
label_train = pd.read_csv('./data/label_train.csv')

param_grid = {
    'n_estimators': [190,120],
    'eta': [0.2],
    'max_depth': [8]
}

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(train, label_train['CIP'], test_size=0.3, random_state=1)

# Perform grid search with cross-validation
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123)
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=5, verbose=1)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the final model with the best hyperparameters
final_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc', seed=123, **best_params)
final_model.fit(X_train, y_train)

# Evaluate the final model on the test set
y_pred = final_model.predict_proba(X_test)[:, 1]
auc_score = roc_auc_score(y_test, y_pred)
print("AUC Score on Test Set:", auc_score)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Best Hyperparameters: {'eta': 0.2, 'max_depth': 8, 'n_estimators': 190}
# AUC Score on Test Set: 0.9649958700400062
